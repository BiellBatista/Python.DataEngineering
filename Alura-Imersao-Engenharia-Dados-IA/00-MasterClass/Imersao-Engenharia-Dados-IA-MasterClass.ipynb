# %%
# https://raw.githubusercontent.com/guilhermeonrails/i-eng-dados-26/refs/heads/main/dados.csv
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/i-eng-dados-26/refs/heads/main/dados.csv") # read the CSV file into a Pandas DataFrame

# %%
df.head(5) # display the first 5 rows
# Out:
#    id_usuario  home  pesquisou_produto  visualizou_detalhes  acessou_faq  \
# 0  USR1000001     1                  1                    1            0
# 1  USR1000002     1                  1                    1            0
# 2  USR1000003     1                  1                    0            1
# 3  USR1000004     1                  1                    1            0
# 4  USR1000005     1                  0                    0            1
#
#    acessou_ofertas  adicionou_carrinho  finalizou_compra codigo_compra  \
# 0                1                   1                 0           NaN
# 1                1                   0                 0           NaN
# 2                1                   0                 0           NaN
# 3                0                   0                 0           NaN
# 4                0                   0                 0           NaN
#
#    valor_total
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info() # display the data types of each column
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_usuario           495000 non-null  str
#  1   home                 500000 non-null  int64
#  2   pesquisou_produto    500000 non-null  int64
#  3   visualizou_detalhes  500000 non-null  int64
#  4   acessou_faq          500000 non-null  int64
#  5   acessou_ofertas      500000 non-null  int64
#  6   adicionou_carrinho   500000 non-null  int64
#  7   finalizou_compra     500000 non-null  int64
#  8   codigo_compra        39726 non-null   str
#  9   valor_total          39726 non-null   float64
# dtypes: float64(1), int64(7), str(2)
# memory usage: 38.1 MB

# %%
df.describe() # display the summary statistics of each column
# Out:
#                home  pesquisou_produto  visualizou_detalhes    acessou_faq  \
# count  500000.00000      500000.000000         500000.00000  500000.000000
# mean        0.93949           0.533002              0.53997       0.468458
# std         0.23843           0.498910              0.49840       0.499005
# min         0.00000           0.000000              0.00000       0.000000
# 25%         1.00000           0.000000              0.00000       0.000000
# 50%         1.00000           1.000000              1.00000       0.000000
# 75%         1.00000           1.000000              1.00000       1.000000
# max         1.00000           1.000000              1.00000       1.000000
#
#        acessou_ofertas  adicionou_carrinho  finalizou_compra   valor_total
# count    500000.000000       500000.000000     500000.000000  39726.000000
# mean          0.200884            0.449874          0.079452   2595.594113
# ...

# %%
df.isnull().sum() # display the number of missing values in each column
# Out:
# id_usuario               5000
# home                        0
# pesquisou_produto           0
# visualizou_detalhes         0
# acessou_faq                 0
# acessou_ofertas             0
# adicionou_carrinho          0
# finalizou_compra            0
# codigo_compra          460274
# valor_total            460274
# dtype: int64

# %%
df.duplicated().sum() # display the number of duplicate
# Out:
# np.int64(4546)

# %%
df["id_usuario"] = df["id_usuario"].fillna("USER_DESCONHECIDO") # fill the missing values in the column 'id_usuario' with the string 'USER_DESCONHECIDO'

# %%
df[df["id_usuario"] == "USER_DESCONHECIDO"] # display the rows where the column 'id_usuario' is equal to 'USER_DESCONHECIDO'
# Out:
#                id_usuario  home  pesquisou_produto  visualizou_detalhes  \
# 212     USER_DESCONHECIDO     1                  0                    0
# 299     USER_DESCONHECIDO     1                  1                    0
# 354     USER_DESCONHECIDO     1                  1                    0
# 569     USER_DESCONHECIDO     1                  0                    0
# 603     USER_DESCONHECIDO     1                  0                    1
# ...                   ...   ...                ...                  ...
# 499648  USER_DESCONHECIDO     1                  1                    1
# 499858  USER_DESCONHECIDO     1                  1                    1
# 499872  USER_DESCONHECIDO     1                  0                    1
# 499908  USER_DESCONHECIDO     1                  1                    1
# 499957  USER_DESCONHECIDO     1                  0                    1
#
#         acessou_faq  acessou_ofertas  adicionou_carrinho  finalizou_compra  \
# ...

# %%
df.isnull().sum() # display the number of missing values in each column
# Out:
# id_usuario                  0
# home                        0
# pesquisou_produto           0
# visualizou_detalhes         0
# acessou_faq                 0
# acessou_ofertas             0
# adicionou_carrinho          0
# finalizou_compra            0
# codigo_compra          460274
# valor_total            460274
# dtype: int64

# %%
import os

os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-26.0.2.1\bin"
os.environ["PATH"] = os.environ["JAVA_HOME"] + r"\bin;" + os.environ["PATH"]

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[2]").appName("Exemplo PySpark").getOrCreate()

dados_spark = spark.createDataFrame(df)
dados_spark.createOrReplaceTempView("dados")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 from pyspark.sql import SparkSession
#       2
# ----> 3 spark = SparkSession.builder.master("local[2]").appName("Exemplo PySpark").getOrCreate()
#       4
#       5 # dados_spark = spark.createDataFrame(df)
#       6 # dados_spark.createOrReplaceTempView("dados")
#
# File C:\Repos\Python.DataEngineering\Alura-Imersao-Engenharia-Dados-IA\.venv\Lib\site-packages\pyspark\sql\session.py:559, in SparkSession.Builder.getOrCreate(self)
#     557     sparkConf.set(key, value)
#     558 # This SparkContext may be an existing one.
# --> 559 sc = SparkContext.getOrCreate(sparkConf)
#     560 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     561 # by all sessions.
#     562 session = SparkSession(sc, options=self._options)
#
# ...

# %%
# %%sql
# SELECT * FROM dados LIMIT 5
